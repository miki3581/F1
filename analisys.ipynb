# %%
import pandas as pd
import numpy as np

# %%
quali22 = pd.read_csv("csv_data/quali_2022.csv")

# %%
quali22.describe()
# Out:
#        DriverNumber    Position  ClassifiedPosition  GridPosition  Time  \
# count    440.000000  440.000000                 0.0           0.0   0.0
# mean      24.850000   10.500000                 NaN           NaN   NaN
# std       21.099509    5.772845                 NaN           NaN   NaN
# min        1.000000    1.000000                 NaN           NaN   NaN
# 25%       10.000000    5.750000                 NaN           NaN   NaN
# 50%       20.000000   10.500000                 NaN           NaN   NaN
# 75%       44.000000   15.250000                 NaN           NaN   NaN
# max       77.000000   20.000000                 NaN           NaN   NaN
#
#        Status  Points  Laps    Year
# count     0.0     0.0   0.0   440.0
# mean      NaN     NaN   NaN  2022.0
# std       NaN     NaN   NaN     0.0
# min       NaN     NaN   NaN  2022.0
# 25%       NaN     NaN   NaN  2022.0
# 50%       NaN     NaN   NaN  2022.0
# 75%       NaN     NaN   NaN  2022.0
# ...

# %%
quali22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DriverNumber        440 non-null    int64
#  1   BroadcastName       440 non-null    object
#  2   Abbreviation        440 non-null    object
#  3   DriverId            440 non-null    object
#  4   TeamName            440 non-null    object
#  5   TeamColor           440 non-null    object
#  6   TeamId              440 non-null    object
#  7   FirstName           440 non-null    object
#  8   LastName            440 non-null    object
#  9   FullName            440 non-null    object
#  10  HeadshotUrl         415 non-null    object
#  11  CountryCode         440 non-null    object
#  12  Position            440 non-null    float64
#  13  ClassifiedPosition  0 non-null      float64
#  14  GridPosition        0 non-null      float64
# ...

# %%
race22 = pd.read_csv("csv_data/race_2022.csv")

# %%
race22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DriverNumber        440 non-null    int64
#  1   BroadcastName       439 non-null    object
#  2   Abbreviation        440 non-null    object
#  3   DriverId            440 non-null    object
#  4   TeamName            440 non-null    object
#  5   TeamColor           439 non-null    object
#  6   TeamId              440 non-null    object
#  7   FirstName           440 non-null    object
#  8   LastName            440 non-null    object
#  9   FullName            440 non-null    object
#  10  HeadshotUrl         414 non-null    object
#  11  CountryCode         439 non-null    object
#  12  Position            439 non-null    float64
#  13  ClassifiedPosition  440 non-null    object
#  14  GridPosition        439 non-null    float64
# ...

# %%
cols_to_drop = [
    "DriverNumber", "BroadcastName", "DriverId", "Abbreviation", 
    "TeamColor", "TeamId", "FirstName", "LastName", "HeadshotUrl", 
    "CountryCode", "Q1", "Q2", "Q3", "Time", "Points", "Laps", "ClassifiedPosition"
]

race22.drop(columns=cols_to_drop, axis=1, inplace=True)

# %%
print(race22.head(20))
# Out:
#            TeamName          FullName  Position  GridPosition         Status  \
# 0           Ferrari   Charles Leclerc       1.0           1.0       Finished
# 1           Ferrari      Carlos Sainz       2.0           3.0       Finished
# 2          Mercedes    Lewis Hamilton       3.0           5.0       Finished
# 3          Mercedes    George Russell       4.0           9.0       Finished
# 4      Haas F1 Team   Kevin Magnussen       5.0           7.0       Finished
# 5        Alfa Romeo   Valtteri Bottas       6.0           6.0       Finished
# 6            Alpine      Esteban Ocon       7.0          11.0       Finished
# 7        AlphaTauri      Yuki Tsunoda       8.0          16.0       Finished
# 8            Alpine   Fernando Alonso       9.0           8.0       Finished
# 9        Alfa Romeo       Guanyu Zhou      10.0          15.0       Finished
# 10     Haas F1 Team   Mick Schumacher      11.0          12.0       Finished
# ...

# %%
cols_to_drop_quali = [
    "DriverNumber", "BroadcastName", "DriverId", "Abbreviation", 
    "TeamColor", "TeamId", "FirstName", "LastName", "HeadshotUrl", 
    "CountryCode", "ClassifiedPosition", "GridPosition", "Time", 
    "Status", "Points", "Laps"
]

# %%
quali22.drop(columns=cols_to_drop_quali, axis=1, inplace=True)

# %%
print(quali22[:20])
# Out:
#            TeamName          FullName  Position                      Q1  \
# 0           Ferrari   Charles Leclerc       1.0  0 days 00:01:31.471000
# 1   Red Bull Racing    Max Verstappen       2.0  0 days 00:01:31.785000
# 2           Ferrari      Carlos Sainz       3.0  0 days 00:01:31.567000
# 3   Red Bull Racing      Sergio Perez       4.0  0 days 00:01:32.311000
# 4          Mercedes    Lewis Hamilton       5.0  0 days 00:01:32.285000
# 5        Alfa Romeo   Valtteri Bottas       6.0  0 days 00:01:31.919000
# 6      Haas F1 Team   Kevin Magnussen       7.0  0 days 00:01:31.955000
# 7            Alpine   Fernando Alonso       8.0  0 days 00:01:32.346000
# 8          Mercedes    George Russell       9.0  0 days 00:01:32.269000
# 9        AlphaTauri      Pierre Gasly      10.0  0 days 00:01:32.096000
# 10           Alpine      Esteban Ocon      11.0  0 days 00:01:32.041000
# 11     Haas F1 Team   Mick Schumacher      12.0  0 days 00:01:32.380000
# ...

# %%
quali22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TeamName   440 non-null    object
#  1   FullName   440 non-null    object
#  2   Position   440 non-null    float64
#  3   Q1         436 non-null    object
#  4   Q2         327 non-null    object
#  5   Q3         212 non-null    object
#  6   Year       440 non-null    int64
#  7   EventName  440 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 27.6+ KB

# %%
import data_loader
import preprocessing

(hist_races, hist_qualis, hist_sprints, hist_sprint_qualis,
 curr_races, curr_qualis, curr_sprints, curr_sprint_qualis) = data_loader.load_all_data()
# Out:
# Fetching historical data for years: [2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025]
# Data for season 2018 loaded from cache.
# Data for season 2019 loaded from cache.
# Data for season 2020 loaded from cache.
# Data for season 2021 loaded from cache.
# Data for season 2022 loaded from cache.
# Data for season 2023 loaded from cache.
# Data for season 2024 loaded from cache.
# Data for season 2025 loaded from cache.
#
# Fetching current season data for year: 2026
# Data for season 2026 loaded from cache.
#
# Historical seasons | Races: 3458 | Qualis: 3459 | Sprints: 240 | Sprint Qualis: 240
# Current season | Races: 66 | Qualis: 66 | Sprints: 22 | Sprint Qualis: 22

# %%
df_historical, df_historical_sprints = preprocessing.process_data(
    hist_races, hist_qualis, hist_sprints, hist_sprint_qualis
)
df_current, df_current_sprints = preprocessing.process_data(
    curr_races, curr_qualis, curr_sprints, curr_sprint_qualis
)

# %%
print(df_current.head())
# Out:
#    TeamName         FullName  Position  GridPosition    Status  Year  \
# 0  Mercedes   George Russell       1.0           1.0  Finished  2026
# 1  Mercedes   Kimi Antonelli       2.0           2.0  Finished  2026
# 2   Ferrari  Charles Leclerc       3.0           4.0  Finished  2026
# 3   Ferrari   Lewis Hamilton       4.0           7.0  Finished  2026
# 4   McLaren     Lando Norris       5.0           6.0  Finished  2026
#
#                EventName  QualiPosition      Q1      Q2      Q3  BestQualiTime
# 0  Australian Grand Prix            1.0  79.507  78.934  78.518         78.518
# 1  Australian Grand Prix            2.0  80.120  79.435  78.811         78.811
# 2  Australian Grand Prix            4.0  80.226  79.357  79.327         79.327
# 3  Australian Grand Prix            7.0  79.811  79.921  79.478         79.478
# 4  Australian Grand Prix            6.0  80.010  79.882  79.475         79.475

# %%
print(df_historical.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3458 entries, 0 to 3457
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TeamName       3458 non-null   object
#  1   FullName       3458 non-null   object
#  2   Position       3455 non-null   float64
#  3   GridPosition   3455 non-null   float64
#  4   Status         3458 non-null   object
#  5   Year           3458 non-null   int64
#  6   EventName      3458 non-null   object
#  7   QualiPosition  3453 non-null   float64
#  8   Q1             3410 non-null   float64
#  9   Q2             2546 non-null   float64
#  10  Q3             1687 non-null   float64
#  11  BestQualiTime  3412 non-null   float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 324.3+ KB
# None

# %%
print(df_historical_sprints.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   TeamName             240 non-null    object
#  1   FullName             240 non-null    object
#  2   Position             240 non-null    float64
#  3   GridPosition         240 non-null    float64
#  4   Status               240 non-null    object
#  5   Year                 240 non-null    int64
#  6   EventName            240 non-null    object
#  7   SprintQualiPosition  0 non-null      float64
#  8   SQ1                  0 non-null      float64
#  9   SQ2                  0 non-null      float64
#  10  SQ3                  0 non-null      float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 20.8+ KB
# None

# %%
print(df_historical_sprints.head())
# Out:
#           TeamName         FullName  Position  GridPosition    Status  Year  \
# 0  Red Bull Racing   Max Verstappen       1.0           4.0  Finished  2024
# 1         Mercedes   Lewis Hamilton       2.0           2.0  Finished  2024
# 2  Red Bull Racing     Sergio Perez       3.0           6.0  Finished  2024
# 3          Ferrari  Charles Leclerc       4.0           7.0  Finished  2024
# 4          Ferrari     Carlos Sainz       5.0           5.0  Finished  2024
#
#             EventName  SprintQualiPosition  SQ1  SQ2  SQ3
# 0  Chinese Grand Prix                  NaN  NaN  NaN  NaN
# 1  Chinese Grand Prix                  NaN  NaN  NaN  NaN
# 2  Chinese Grand Prix                  NaN  NaN  NaN  NaN
# 3  Chinese Grand Prix                  NaN  NaN  NaN  NaN
# 4  Chinese Grand Prix                  NaN  NaN  NaN  NaN

# %%
print(df_current_sprints.head())
# Out:
#    TeamName         FullName  Position  GridPosition    Status  Year  \
# 0  Mercedes   George Russell       1.0           1.0  Finished  2026
# 1   Ferrari  Charles Leclerc       2.0           6.0  Finished  2026
# 2   Ferrari   Lewis Hamilton       3.0           4.0  Finished  2026
# 3   McLaren     Lando Norris       4.0           3.0  Finished  2026
# 4  Mercedes   Kimi Antonelli       5.0           2.0  Finished  2026
#
#             EventName  SprintQualiPosition  SQ1  SQ2  SQ3
# 0  Chinese Grand Prix                  NaN  NaN  NaN  NaN
# 1  Chinese Grand Prix                  NaN  NaN  NaN  NaN
# 2  Chinese Grand Prix                  NaN  NaN  NaN  NaN
# 3  Chinese Grand Prix                  NaN  NaN  NaN  NaN
# 4  Chinese Grand Prix                  NaN  NaN  NaN  NaN

# %%
from preprocessing import clean_race_data, clean_sprint_data, clean_sprint_quali_data
df_sprints_clean = clean_sprint_data(df_current_sprints)
print(df_sprints_clean.head())
# Out:
#    TeamName         FullName  Position  GridPosition    Status  Year  \
# 0  Mercedes   George Russell       1.0           1.0  Finished  2026
# 1   Ferrari  Charles Leclerc       2.0           6.0  Finished  2026
# 2   Ferrari   Lewis Hamilton       3.0           4.0  Finished  2026
# 3   McLaren     Lando Norris       4.0           3.0  Finished  2026
# 4  Mercedes   Kimi Antonelli       5.0           2.0  Finished  2026
#
#             EventName
# 0  Chinese Grand Prix
# 1  Chinese Grand Prix
# 2  Chinese Grand Prix
# 3  Chinese Grand Prix
# 4  Chinese Grand Prix

# %%
df_sprint_quali_clean = clean_sprint_quali_data(df_current_sprint_qualis)
print(df_sprints_clean.head())
